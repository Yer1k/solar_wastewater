# %%
import geopandas as gpd

# %%
# read in geopanda folder
gdf = gpd.read_file('../00_source_data/FRS_Wastewater/CWA_summaries_060314.gdb')

# %%
# show random 10 rows
gdf.sample(10)
# Out:
#         SOURCE_ID EPA_SYSTEM   REGISTRY_ID STATUTE  \
# 325740  LAJ660102        ICP  110006027977     CWA
# 41094   NYAE00372        ICP  110010804692     CWA
# 449852  LAG532024        ICP  110025186439     CWA
# 453882  WV0101745        ICP  110054999800     CWA
# 133030  KYU098230        ICP  110033016616     CWA
# 413004  ALR10AA78        ICP  110055360737     CWA
# 256244  OH0135437        ICP  110017695074     CWA
# 5273    NCG500134        ICP  110018514473     CWA
# 459241  ALG230028        ICP  110000790047     CWA
# 380643  LAR05P122        ICP  110011411784     CWA
#
#                                    CWP_NAME                     CWP_STREET  \
# 325740                    R.R. CASSIDY INC.                  37471 HWY 427
# 41094                      BASKIN LIVESTOCK                9778 CREEK ROAD
# 449852  MAC-NETT ENVIRONMENTAL SERVICES LLC           672 A.O. RAPPLETE RD
# 453882             MARTHA ELEMENTARY SCHOOL                        UNKNOWN
# 133030           BATH CO PARKS & RECREATION                   PEASTICKS RD
# 413004                                  PDQ      116 SOUTH UNIVERSITY BLVD
# 256244          MARION COUNTY COMMISSIONERS  THE GROVES AT NEWMAN CROSSING
# 5273           ROANOKE RAPIDS HYDRO STATION                100 OAKWOOD AVE
# 459241                        EUFAULA PLANT                  36 ARCH DRIVE
# 380643            AMAX METALS RECOVERY INC.         3607 ENGLISH TURN ROAD
#
#               CWP_CITY CWP_STATE  CWP_STATE_DISTRICT CWP_ZIP  ...  \
# 325740    PRAIRIEVILLE        LA                 NaN   70769  ...
# 41094          BETHANY        NY                 NaN   14020  ...
# 449852   GOLDEN MEADOW        LA                 NaN   70357  ...
# 453882   BARBOURSVILLE        WV                 NaN   25504  ...
# 133030     OWINGSVILLE        KY                 NaN   40360  ...
# 413004          MOBILE        AL                 NaN   36608  ...
# 256244          MARION        OH                 NaN   43302  ...
# 5273    ROANOKE RAPIDS        NC                 NaN   27870  ...
# 459241         EUFAULA        AL                 NaN   36027  ...
# 380643     BRAITHWAITE        LA                 NaN   70040  ...
#
#        CWP_COMPLIANCE_TRACKING FAC_TRI_REPORTER CWP_CURRENT_VIOL13  \
# 325740                      On              NaN                NaN
# 41094                      Off              NaN                NaN
# 449852                      On              NaN                NaN
# 453882                     Off              NaN                NaN
# 133030                     NaN              NaN                NaN
# 413004                     Off              NaN                NaN
# 256244                      On              NaN                Yes
# 5273                        On              NaN                NaN
# 459241                      On                B                Yes
# 380643                      On                P                NaN
#
#        CWP_13QTRS_COMPL_STATUS SIC_CODES NAICS_CODES CASE_IDS  \
# 325740           _____________       NaN         NaN      NaN
# 41094            ____VV_____U_      0291         NaN      NaN
# 449852           _____________      4225         NaN      NaN
# 453882           _____________      8211         NaN      NaN
# 133030           _____________       NaN         NaN      NaN
# 413004           ___________U_      1531         NaN      NaN
# 256244           ______VVVVVVV      4952         NaN      NaN
# 5273             _____________       NaN         NaN      NaN
# 459241           ___________V_      3295         NaN      NaN
# 380643           _____________       NaN         NaN      NaN
#
#        STATE_WATER_BODY STATE_WATER_BODY_NAME  \
# 325740              NaN                   NaN
# 41094               NaN                   NaN
# 449852         08090301                   NaN
# 453882              NaN                   NaN
# 133030              NaN                   NaN
# 413004              NaN                   NaN
# 256244         05060001          QU QUA DITCH
# 5273                NaN                   NaN
# 459241              NaN                   NaN
# 380643              NaN                   NaN
#
#                                  geometry
# 325740  POINT (-10128283.311 3546476.278)
# 41094    POINT (-8703421.436 5303141.583)
# 449852  POINT (-10040461.472 3391175.948)
# 453882   POINT (-9159714.017 4633290.480)
# 133030   POINT (-9318845.897 4600371.384)
# 413004   POINT (-9815025.143 3591724.063)
# 256244   POINT (-9249338.564 4938690.283)
# 5273     POINT (-8646430.087 4366776.814)
# 459241   POINT (-9479529.126 3747171.578)
# 380643  POINT (-10015531.361 3485899.911)
#
# [10 rows x 54 columns]

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
# show column names
gdf.columns
# Out:
# Index(['SOURCE_ID', 'EPA_SYSTEM', 'REGISTRY_ID', 'STATUTE', 'CWP_NAME',
#        'CWP_STREET', 'CWP_CITY', 'CWP_STATE', 'CWP_STATE_DISTRICT', 'CWP_ZIP',
#        'CWP_COUNTY', 'CWP_EPA_REGION', 'CWP_STATUS', 'CWP_INDIAN_CNTRY_FLG',
#        'CWP_TRIBAL_LAND_CODE', 'CWP_PERMIT_STATUS_CODE',
#        'CWP_PERMIT_STATUS_DESC', 'CWP_PERMIT_TYPE_CODE',
#        'CWP_PERMIT_TYPE_DESC', 'CWP_EXPIRATION_DATE',
#        'CWP_FACILITY_TYPE_INDICATOR', 'CWP_MAJOR_MINOR_STATUS_FLAG',
#        'FAC_FEDERAL_AGENCY_CODE', 'CWP_CURRENT_SNC_STATUS',
#        'CWP_SNC_EVENT_DESC', 'CWP_CURRENT_SNC_STATUS_DATE', 'CWP_CURRENT_VIOL',
#        'CWP_DATE_LAST_INSPECTION', 'CWP_DATE_LAST_INFORMAL_EA',
#        'FAC_US_MEX_BORDER_FLG', 'CWP_IMP_WATER_FLG', 'FAC_DERIVED_HUC',
#        'FAC_MAP_FLG', 'FAC_MAP_ICON', 'FAC_FIPS_CODE', 'CWP_CSO_FLAG',
#        'CWP_DATE_LAST_FEA', 'CWP_DATE_LAST_FEA_ST', 'CWP_DATE_LAST_FEA_EPA',
#        'CWP_DATE_LAST_IEA_ST', 'CWP_DATE_LAST_IEA_EPA',
#        'CWP_DATE_LAST_INSP_EPA', 'CWP_DATE_LAST_INSP_ST',
#        'CWP_DATE_LAST_PENALTY', 'CWP_COMPLIANCE_TRACKING', 'FAC_TRI_REPORTER',
#        'CWP_CURRENT_VIOL13', 'CWP_13QTRS_COMPL_STATUS', 'SIC_CODES',
#        'NAICS_CODES', 'CASE_IDS', 'STATE_WATER_BODY', 'STATE_WATER_BODY_NAME',
#        'geometry'],
#       dtype='object')

# %%
gdf_CA = gdf[gdf['CWP_STATE'] == 'CA']

# %%
gdf_CA.sample(10)
# Out:
#         SOURCE_ID EPA_SYSTEM   REGISTRY_ID STATUTE  \
# 252916  CA0081639        ICP  110002148603     CWA
# 446963  CAU000195        ICP  110010061002     CWA
# 351827  CAA000059        ICP  110006784550     CWA
# 434566  CA0023981        ICP  110037254752     CWA
# 339054  CA0037788        ICP  110055988016     CWA
# 380266  CAU001106        ICP  110054108489     CWA
# 379051  CA0047830        ICP  110055986562     CWA
# 102138  CAF001080        ICP  110035769692     CWA
# 45949   CAU000400        ICP  110011373824     CWA
# 162823  CA0000035        ICP  110000476235     CWA
#
#                               CWP_NAME                    CWP_STREET  \
# 252916  BELL-CARTER OLIVE COMPANY, INC                       PLANT 1
# 446963        HEAVENLY VALLYE SKI AREA               HEAVENLY VALLEY
# 351827           FOSTER FARMS DAIRY #6            6311 E MONTE VISTA
# 434566                         UNKNOWN                       UNKNOWN
# 339054                 BURLINGAME WWTF        1103 AIRPORT BOULEVARD
# 380266              LAKE ARROWHEAD CSD         840 WILLOW CREEK ROAD
# 379051            AVILA BEACH CSD WWTP           2850 AVILA BEACH DR
# 102138                NUSTAR ENERGY LP  STOCKTON ROUGH & READY TERM.
# 45949       MISSION CANYON LANDFILL #6    22751 GOLDEN SPRINGS DRIVE
# 162823    LAREFINERY, WILMINGTON PLANT             1660 W ANAHEIM ST
#
#                 CWP_CITY CWP_STATE  CWP_STATE_DISTRICT CWP_ZIP  ...  \
# 252916           CORNING        CA                 NaN   96021  ...
# 446963  SOUTH LAKE TAHOE        CA                 NaN   96156  ...
# 351827            DENAIR        CA                 NaN   95316  ...
# 434566               NaN        CA                 NaN   00000  ...
# 339054        BURLINGAME        CA                 NaN   94010  ...
# 380266    LAKE ARROWHEAD        CA                 NaN   92352  ...
# 379051       AVILA BEACH        CA                 NaN   93424  ...
# 102138          STOCKTON        CA                 NaN   95206  ...
# 45949        DIAMOND BAR        CA                 NaN   91765  ...
# 162823        WILMINGTON        CA                 NaN   90744  ...
#
#        CWP_COMPLIANCE_TRACKING FAC_TRI_REPORTER CWP_CURRENT_VIOL13  \
# 252916                     Off                P                NaN
# 446963                     NaN              NaN                NaN
# 351827                     NaN              NaN                NaN
# 434566                     Off              NaN                NaN
# 339054                      On              NaN                Yes
# 380266                     NaN              NaN                NaN
# 379051                     Off              NaN                NaN
# 102138                      On              NaN                NaN
# 45949                      NaN              NaN                NaN
# 162823                     Off                B                NaN
#
#        CWP_13QTRS_COMPL_STATUS SIC_CODES NAICS_CODES CASE_IDS  \
# 252916           __UUUUUUUU___      2033         NaN      NaN
# 446963           _____________       NaN         NaN      NaN
# 351827           _____________      0241         NaN      NaN
# 434566           _____________      2493         NaN      NaN
# 339054           VV_V________V      4952         NaN      NaN
# 380266           _____________       NaN         NaN      NaN
# 379051           __UUUUUUUUUU_       NaN         NaN      NaN
# 102138           _____________      4226         NaN      NaN
# 45949            _____________       NaN         NaN      NaN
# 162823           _____________      2911         NaN      NaN
#
#        STATE_WATER_BODY    STATE_WATER_BODY_NAME  \
# 252916     180201030080             JEWETT CREEK
# 446963              NaN                      NaN
# 351827              NaN                      NaN
# 434566     180101020100              JANES CREEK
# 339054     180500040010  Lower San Francisco Bay
# 380266              NaN                      NaN
# 379051     180600060000            PACIFIC OCEAN
# 102138              NaN                      NaN
# 45949               NaN                      NaN
# 162823     180701040010       LOS ANGELES HARBOR
#
#                                  geometry
# 252916  POINT (-13600800.538 4855091.558)
# 446963  POINT (-13355095.045 4712781.611)
# 351827  POINT (-13444828.017 4512068.814)
# 434566  POINT (-13813079.015 4993434.939)
# 339054  POINT (-13620841.164 4521934.162)
# 380266  POINT (-13045027.294 4064518.923)
# 379051  POINT (-13439936.082 4188641.805)
# 102138  POINT (-13508261.202 4572224.997)
# 45949   POINT (-13115671.534 4029815.986)
# 162823  POINT (-13168060.044 3998558.776)
#
# [10 rows x 54 columns]

# %%
# filter CWP_NAME with WWTP or WWTF in it
gdf_CA_WWTP = gdf_CA[gdf_CA['CWP_NAME'].str.contains('WWTP|WWTF')]

# %%
gdf_CA_WWTP
# Out:
#         SOURCE_ID EPA_SYSTEM   REGISTRY_ID STATUTE  \
# 154     CA0024040        ICP  110009126917     CWA
# 375     CA0104426        ICP  110000759402     CWA
# 376     CA0084611        ICP  110037254173     CWA
# 427     CA0084239        ICP  110002041362     CWA
# 433     CA0078590        ICP  110001103911     CWA
# ...           ...        ...           ...     ...
# 490178  CA0053961        ICP  110000915421     CWA
# 490302  CA0078441        ICP  110006783579     CWA
# 490496  CA0105023        ICP  110006657554     CWA
# 490628  CA0037851        ICP  110010474753     CWA
# 490852  CA0079022        ICP  110000736311     CWA
#
#                               CWP_NAME                 CWP_STREET  \
# 154                    ANCHOR BAY WWTF    46890 GETCHELL GULCH RD
# 375                     EL CENTRO WWTP     2255 N LA BRUCHERIE RD
# 376     SIERRA CONSERVATION CTR-WWTP-2     5100 O'BYRNES FERRY RD
# 427                        MALAGA WWTF    3749 SOUTH MAPLE AVENUE
# 433                 DISCOVERY BAY WWTP      1800 WILLOW LAKE ROAD
# ...                                ...                        ...
# 490178                OJAI VALLEY WWTP  6363 NORTH VENTURA AVENUE
# 490302                   DUNSMUIR WWTP    1100 SOUTH FIRST STREET
# 490496              SEELEY COUNTY WWTP      1898 WEST MAIN STREET
# 490628               LAS GALLINAS WWTP         300 SMITH RANCH RD
# 490852                   LIVE OAK WWTP  3450 TREATMENT PLANT ROAD
#
#              CWP_CITY CWP_STATE  CWP_STATE_DISTRICT     CWP_ZIP  ...  \
# 154        ANCHOR BAY        CA                 NaN       95445  ...
# 375         EL CENTRO        CA                 NaN       92243  ...
# 376         JAMESTOWN        CA                 NaN       95327  ...
# 427            FRESNO        CA                 NaN       93725  ...
# 433     DISCOVERY BAY        CA                 NaN       94505  ...
# ...               ...       ...                 ...         ...  ...
# 490178        VENTURA        CA                 NaN  93001-1004  ...
# 490302       DUNSMUIR        CA                 NaN       96025  ...
# 490496         SEELEY        CA                 NaN       92273  ...
# 490628     SAN RAFAEL        CA                 NaN       94903  ...
# 490852       LIVE OAK        CA                 NaN       95953  ...
#
#        CWP_COMPLIANCE_TRACKING FAC_TRI_REPORTER CWP_CURRENT_VIOL13  \
# 154                        Off              NaN                NaN
# 375                         On              NaN                Yes
# 376                        Off              NaN                NaN
# 427                         On              NaN                Yes
# 433                         On              NaN                Yes
# ...                        ...              ...                ...
# 490178                      On              NaN                NaN
# 490302                     Off              NaN                Yes
# 490496                     Off              NaN                NaN
# 490628                      On              NaN                NaN
# 490852                      On              NaN                Yes
#
#        CWP_13QTRS_COMPL_STATUS SIC_CODES NAICS_CODES  \
# 154              __UUUUUUUUUU_      4952         NaN
# 375              VVV__V_VVVVVV      4952         NaN
# 376              _____________      9223         NaN
# 427              V___V___VSVVV      4952         NaN
# 433              VVVV_VVVVVVVV      4952         NaN
# ...                        ...       ...         ...
# 490178           VV______V_V__      4952         NaN
# 490302           VVVVVVVVVVVVV      4952         NaN
# 490496           __UUUUUUUUUU_      4952         NaN
# 490628           SVVV_________      4952         NaN
# 490852           S__VVVVSSVVVV      4952         NaN
#
#                                                  CASE_IDS STATE_WATER_BODY  \
# 154                                                   NaN     180101080010
# 375                             CA-2010-1160 CA-2009-1156     181002000120
# 376                                                   NaN              NaN
# 427                                          CA-2013-1075              NaN
# 433     CA-2013-1047 CA-2011-1063 CA-2009-1131 CA-2009...     180500010000
# ...                                                   ...              ...
# 490178                                       CA-2009-1199     180701010020
# 490302                          CA-2010-1077 CA-2012-1081     180200050200
# 490496             CA-2011-1138 CA-2012-1004 CA-2009-1163         18100200
# 490628                                       CA-2010-1000         18050002
# 490852  CA-2012-1067 CA-2009-1097 CA-2009-1029 CA-2009...     180201060000
#
#        STATE_WATER_BODY_NAME                           geometry
# 154            PACIFIC OCEAN  POINT (-13757913.974 4694055.563)
# 375            CENTRAL DRAIN  POINT (-12866198.655 3870715.031)
# 376                      NaN  POINT (-13419740.834 4564411.447)
# 427            CENTRAL CANAL  POINT (-13330196.883 4394573.934)
# 433                OLD RIVER  POINT (-13535027.640 4564564.219)
# ...                      ...                                ...
# 490178         Ventura River  POINT (-13280331.317 4075167.643)
# 490302      Sacramento River  POINT (-13612617.102 5039456.759)
# 490496             New River  POINT (-12879186.411 3868231.089)
# 490628         SAN PABLO BAY  POINT (-13638864.012 4582997.362)
# 490852            Sacramento  POINT (-13545201.017 4758903.129)
#
# [408 rows x 54 columns]

# %%
# change CRS to EPSG:4326
gdf_CA_WWTP.to_crs(epsg=4326, inplace=True)
# Out:
# /Users/yer1k/miniconda3/envs/osm/lib/python3.11/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
gdf_CA_WWTP.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# plot geometry of gdf_CA_WWTP on a US map with CA state boundary
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon
# import contextily as cx

# create a US map
fig, ax = plt.subplots(figsize=(12,12))
gdf_CA_WWTP.plot(ax=ax, alpha=0.4)

plt.axis('off')
plt.show()
