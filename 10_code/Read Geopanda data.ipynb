# %%
import geopandas as gpd

# %%
# read in geopanda folder
gdf = gpd.read_file('../00_source_data/FRS_Wastewater/CWA_summaries_060314.gdb')

# %%
# show random 10 rows
gdf.sample(10)
# Out:
#         SOURCE_ID EPA_SYSTEM   REGISTRY_ID STATUTE  \
# 449374  MD0068179        ICP  110006744283     CWA
# 385730  IN0003778        ICP  110028080225     CWA
# 158220  LAG533594        ICP  110043269691     CWA
# 123009  MTR102828        ICP  110033201728     CWA
# 142103  AL0041726        ICP  110009121976     CWA
# 312809  FLR10GZ16        ICP  110020171286     CWA
# 368416  WVG551069        ICP  110011529612     CWA
# 390462  FLR10FL76        ICP  110032810484     CWA
# 8055    ALR163544        ICP  110020531502     CWA
# 328895  LAG480173        ICP  110001317487     CWA
#
#                                                  CWP_NAME  \
# 449374  SNOW HILL DISTRICT COURT - SOCIAL SERVICES COM...
# 385730                        NORFOLK SOUTHERN RAILWAY CO
# 158220                                    CUZ STORAGE LLC
# 123009                BURLINGTON RESOURCES - BR 41-29H 28
# 142103     WALKER CO BOE CURRY ELEMENTARY AND HIGH SCHOOL
# 312809                            NORTH RIDGE SUBDIVISION
# 368416                     WASHINGTON DISTRICT ELEMENTARY
# 390462                                  SOUTHPOINTE PLAZA
# 8055                                WHITE OAK GOLF COURSE
# 328895                        HALLIBURTON ENERGY SERVICES
#
#                           CWP_STREET       CWP_CITY CWP_STATE  \
# 449374     299 - 301 COMMERCE STREET      SNOW HILL        MD
# 385730                333 N SMITH ST           PERU        IN
# 158220                   3810 HWY 56          HOUMA        LA
# 123009                  SW OF SIDNEY         SIDNEY        MT
# 142103        85 YELLOW JACKET DRIVE         JASPER        AL
# 312809  SR 11 NEAR EVERGREEN TERRACE         DELAND        FL
# 368416                HC 36, BOX 234     BUCKHANNON        WV
# 390462              580 US HIGHWAY 1     VERO BEACH        FL
# 8055               DONALD W BOUTWELL     GREENVILLE        AL
# 328895              182 N. DOUCET DR  GOLDEN MEADOW        LA
#
#         CWP_STATE_DISTRICT    CWP_ZIP  ... CWP_COMPLIANCE_TRACKING  \
# 449374                 NaN      21863  ...                      On
# 385730                 NaN  469701376  ...                     Off
# 158220                 NaN      70363  ...                      On
# 123009                 NaN      59270  ...                     Off
# 142103                 NaN      35503  ...                      On
# 312809                 NaN      32720  ...                     Off
# 368416                 NaN      26201  ...                      On
# 390462                 NaN      32962  ...                     Off
# 8055                   NaN      36037  ...                     Off
# 328895                 NaN      70357  ...                      On
#
#        FAC_TRI_REPORTER CWP_CURRENT_VIOL13 CWP_13QTRS_COMPL_STATUS SIC_CODES  \
# 449374              NaN                Yes           UUUUUUU__VVV_      9211
# 385730              NaN                NaN           _____________      4011
# 158220              NaN                NaN           _____________      4225
# 123009              NaN                NaN           __VVV_UU_____      1629
# 142103              NaN                NaN           SSV_V_VSSS___      8211
# 312809              NaN                NaN           __________UU_       NaN
# 368416              NaN                NaN           _____________      4952
# 390462              NaN                NaN           ________U____       NaN
# 8055                NaN                NaN           _____________       NaN
# 328895              NaN                NaN           _____________      1389
#
#        NAICS_CODES CASE_IDS STATE_WATER_BODY  \
# 449374         NaN      NaN              NaN
# 385730         NaN      NaN     051201010001
# 158220         NaN      NaN              NaN
# 123009         NaN      NaN              NaN
# 142103         NaN      NaN         03160109
# 312809         NaN      NaN              NaN
# 368416         NaN      NaN         05020001
# 390462         NaN      NaN              NaN
# 8055           NaN      NaN              NaN
# 328895         NaN      NaN         08090301
#
#                       STATE_WATER_BODY_NAME                           geometry
# 449374               POCOMOKE RIVER - LOWER   POINT (-8392963.955 4604963.813)
# 385730                                    Í   POINT (-9579623.159 4977531.327)
# 158220                                  NaN  POINT (-10090585.299 3447144.560)
# 123009                     NORTH FORK CREEK  POINT (-11610019.872 6047822.902)
# 142103                     UT TO ROCK CREEK   POINT (-9708967.502 4023070.705)
# 312809                                  NaN   POINT (-9050837.656 3386909.963)
# 368416  UNT/TRUBIE RN RM 2.21/BUCKHANNON RV   POINT (-8923905.049 4716945.851)
# 390462                                  NaN   POINT (-8948231.698 3200031.670)
# 8055                                    NaN   POINT (-9647503.670 3746840.711)
# 328895                                  NaN  POINT (-10042665.598 3391453.107)
#
# [10 rows x 54 columns]

# %%
# show column names
gdf.columns
# Out:
# Index(['SOURCE_ID', 'EPA_SYSTEM', 'REGISTRY_ID', 'STATUTE', 'CWP_NAME',
#        'CWP_STREET', 'CWP_CITY', 'CWP_STATE', 'CWP_STATE_DISTRICT', 'CWP_ZIP',
#        'CWP_COUNTY', 'CWP_EPA_REGION', 'CWP_STATUS', 'CWP_INDIAN_CNTRY_FLG',
#        'CWP_TRIBAL_LAND_CODE', 'CWP_PERMIT_STATUS_CODE',
#        'CWP_PERMIT_STATUS_DESC', 'CWP_PERMIT_TYPE_CODE',
#        'CWP_PERMIT_TYPE_DESC', 'CWP_EXPIRATION_DATE',
#        'CWP_FACILITY_TYPE_INDICATOR', 'CWP_MAJOR_MINOR_STATUS_FLAG',
#        'FAC_FEDERAL_AGENCY_CODE', 'CWP_CURRENT_SNC_STATUS',
#        'CWP_SNC_EVENT_DESC', 'CWP_CURRENT_SNC_STATUS_DATE', 'CWP_CURRENT_VIOL',
#        'CWP_DATE_LAST_INSPECTION', 'CWP_DATE_LAST_INFORMAL_EA',
#        'FAC_US_MEX_BORDER_FLG', 'CWP_IMP_WATER_FLG', 'FAC_DERIVED_HUC',
#        'FAC_MAP_FLG', 'FAC_MAP_ICON', 'FAC_FIPS_CODE', 'CWP_CSO_FLAG',
#        'CWP_DATE_LAST_FEA', 'CWP_DATE_LAST_FEA_ST', 'CWP_DATE_LAST_FEA_EPA',
#        'CWP_DATE_LAST_IEA_ST', 'CWP_DATE_LAST_IEA_EPA',
#        'CWP_DATE_LAST_INSP_EPA', 'CWP_DATE_LAST_INSP_ST',
#        'CWP_DATE_LAST_PENALTY', 'CWP_COMPLIANCE_TRACKING', 'FAC_TRI_REPORTER',
#        'CWP_CURRENT_VIOL13', 'CWP_13QTRS_COMPL_STATUS', 'SIC_CODES',
#        'NAICS_CODES', 'CASE_IDS', 'STATE_WATER_BODY', 'STATE_WATER_BODY_NAME',
#        'geometry'],
#       dtype='object')
